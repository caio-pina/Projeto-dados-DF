# %% [markdown]
# ___
#
# ![IDP](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQwexdWEPU18QMk0MOVrrfdwuxT76ZTviSraUDPeryDIw&s)
# ___

# %%
import pandas as pd
import matplotlib.pyplot as plt
df3 = pd.read_csv('/content/df3')
# %matplotlib inline

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %% [markdown]
# ** Recrie este gráfico de dispersão de b vs a. Observe a cor e o tamanho dos pontos. Observe também o tamanho da figura. Veja se você consegue descobrir como esticá-lo de maneira semelhante. Lembre-se de voltar à sua palestra sobre matplotlib...**

# %% [markdown]
# ## Gráfico de dispersão de b vs a.

# %%
df3.plot.scatter(x='b', y='a', figsize=(20, 4), color='purple')

plt.show()

# %% [markdown]
# ** Crie um histograma da coluna 'a'.**

# %% [markdown]
# # Histograma da coluna A

# %%
df3['a'].hist(bins= 80, color='red' )
# Out:
# <Axes: >

# %% [markdown]
# ** Esses gráficos são bons, mas não parecem muito polidos. Use folhas de estilo para definir o estilo como 'ggplot' e refaça o histograma acima. Descubra também como adicionar mais caixas a ele.***

# %% [markdown]
# # Histograma com estilo gpilot e barras definidas

# %%
df3['a'].hist(bins=30, edgecolor='black', color='orange')
plt.xlabel('Valor de a')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %% [markdown]
# ** Crie um boxplot comparando as colunas aeb.**

# %% [markdown]
# # Boxplot

# %%
df3[['a', 'b']].boxplot()

plt.ylabel('Valores')
plt.title('Boxplot Comparando Colunas a e b')
# Out:
# Text(0.5, 1.0, 'Boxplot Comparando Colunas a e b')

# %% [markdown]
# ** Crie um gráfico kde da coluna 'd' **

# %%
df3['d'].plot.kde()
plt.xlabel('Valor de d')
plt.ylabel('Densidade')
plt.title('Gráfico KDE da Coluna d')
# Out:
# Text(0.5, 1.0, 'Gráfico KDE da Coluna d')

# %% [markdown]
# ** Descubra como aumentar a largura da linha e tornar o estilo de linha tracejado. (Nota: você normalmente não traçaria uma linha de enredo do kde)**

# %%
df3['d'].plot.kde(color='#C8A2C8', linewidth=5, linestyle='--')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ##Grafico para teste multi-color

# %%
cores_arcoiris = plt.cm.rainbow(np.linspace(0, 1, len(df3.columns)))
for i, coluna in enumerate(df3.columns):
    df3[coluna].plot.kde(color=cores_arcoiris[i], linestyle='--', linewidth=2, label=coluna)
plt.legend('Grafico para testeste multi-color, Eu criei esse grafico para ver se tem alguem copiando meu deveres ')

# %% [markdown]
# ** Crie um gráfico de área de todas as colunas apenas para as linhas até 30. (dica: use .ix).**

# %%
df3.iloc[:40].plot.area(alpha=0.8)
# Out:
# <Axes: >

# %% [markdown]
# ## Desafio bônus!
# Observe que você pode achar isso muito difícil, consulte as soluções se não conseguir descobrir!
# ** Observe como a legenda em nossa figura anterior se sobrepôs a parte do diagrama real. Você consegue descobrir como exibir a legenda fora do gráfico, conforme mostrado abaixo?**
#
# ** Tente pesquisar no Google um bom link stackoverflow sobre este tópico. Se você não conseguir encontrar sozinho - [use este como dica.](http://stackoverflow.com/questions/23556153/how-to-put-legend-outside-the-plot-with-pandas )**

# %%
ax = df3.iloc[:40].plot.area(alpha=0.8)
plt.title('Gráfico de área até a linha 30', color='Red')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.9))

# %% [markdown]
# # Great Job!
